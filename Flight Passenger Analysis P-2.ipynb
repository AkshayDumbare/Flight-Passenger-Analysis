# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("D:\\Data science\\Project\\Flight Passenger analysis using Python\\passenger data.csv")

# %%
data1.head()
# Out:
#        id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0  114960  Female  Loyal Customer   55  Business travel  Business
# 1   43337    Male  Loyal Customer   36  Business travel       Eco
# 2   74692  Female  Loyal Customer   17  Personal Travel       Eco
# 3   98299  Female  Loyal Customer   11  Personal Travel       Eco
# 4   70039    Male  Loyal Customer   39  Business travel       Eco
#
#    Flight Distance
# 0             2001
# 1              387
# 2             1235
# 3             1072
# 4              183

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122454 entries, 0 to 122453
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               122454 non-null  int64
#  1   Gender           122454 non-null  object
#  2   Customer Type    122454 non-null  object
#  3   Age              122454 non-null  int64
#  4   Type of Travel   122454 non-null  object
#  5   Class            122454 non-null  object
#  6   Flight Distance  122454 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 6.5+ MB

# %%
data1.isnull().sum()
# Out:
# id                 0
# Gender             0
# Customer Type      0
# Age                0
# Type of Travel     0
# Class              0
# Flight Distance    0
# dtype: int64

# %%
data2=pd.read_csv("D:\\Data science\\Project\\Flight Passenger analysis using Python\\survery data.csv")

# %%
data2.head()
# Out:
#        id  Inflight wifi service  Departure/Arrival time convenient  \
# 0   70172                      3                                  4
# 1    5047                      3                                  2
# 2  110028                      2                                  2
# 3   24026                      2                                  5
# 4  119299                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
# 2             5                       5                 4                 3
# 3             2                       2                 2                 5
# 4             5                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   Inflight wifi service              129880 non-null  int64
#  2   Departure/Arrival time convenient  129880 non-null  int64
#  3   Ease of Online booking             129880 non-null  int64
#  4   Gate location                      129880 non-null  int64
#  5   Food and drink                     129880 non-null  int64
#  6   Online boarding                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Inflight entertainment             129880 non-null  int64
#  9   On-board service                   129880 non-null  int64
#  10  Leg room service                   129880 non-null  int64
#  11  Baggage handling                   129880 non-null  int64
#  12  Checkin service                    129880 non-null  int64
#  13  Inflight service                   129880 non-null  int64
#  14  Cleanliness                        129880 non-null  int64
#  15  Departure Delay in Minutes         129880 non-null  int64
#  16  Arrival Delay in Minutes           129487 non-null  float64
#  17  satisfaction                       129880 non-null  object
# dtypes: float64(1), int64(16), object(1)
# memory usage: 17.8+ MB

# %%
data2.isnull().sum()
# Out:
# id                                     0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# dtype: int64

# %%
df=pd.merge(data1,data2)

# %%
df.head()
# Out:
#        id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0  114960  Female  Loyal Customer   55  Business travel  Business
# 1  114960  Female  Loyal Customer   55  Business travel  Business
# 2   43337    Male  Loyal Customer   36  Business travel       Eco
# 3   43337    Male  Loyal Customer   36  Business travel       Eco
# 4   74692  Female  Loyal Customer   17  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             2001                      2                                  2
# 1             2001                      2                                  2
# 2              387                      3                                  5
# 3              387                      3                                  5
# 4             1235                      3                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       2  ...                       4                 4
# 1                       2  ...                       4                 4
# 2                       2  ...                       3                 1
# 3                       2  ...                       3                 1
# 4                       3  ...                       4                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 4                 4                4                 4
# 1                 4                 4                4                 4
# 2                 1                 1                2                 1
# 3                 1                 1                2                 1
# 4                 5                 5                3                 4
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            3                          24                      21.0
# 1            3                          24                      21.0
# 2            3                           0                       1.0
# 3            3                           0                       1.0
# 4            4                           3                       0.0
#
#               satisfaction
# 0                satisfied
# 1                satisfied
# 2  neutral or dissatisfied
# 3  neutral or dissatisfied
# 4  neutral or dissatisfied
#
# [5 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             369
# satisfaction                           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (122085, 24)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (120634, 24)

# %%
df=df.set_index('id')

# %%
df['satisfaction'] = df['satisfaction'].map(lambda x : 'Yes' if (x== 'satisfied') else 'No')

# %%
df.columns=df.columns.str.title()

# %%
df.head()
# Out:
#         Gender   Customer Type  Age   Type Of Travel     Class  \
# id
# 114960  Female  Loyal Customer   55  Business travel  Business
# 43337     Male  Loyal Customer   36  Business travel       Eco
# 74692   Female  Loyal Customer   17  Personal Travel       Eco
# 98299   Female  Loyal Customer   11  Personal Travel       Eco
# 70039     Male  Loyal Customer   39  Business travel       Eco
#
#         Flight Distance  Inflight Wifi Service  \
# id
# 114960             2001                      2
# 43337               387                      3
# 74692              1235                      3
# 98299              1072                      3
# 70039               183                      4
#
#         Departure/Arrival Time Convenient  Ease Of Online Booking  \
# id
# 114960                                  2                       2
# 43337                                   5                       2
# 74692                                   4                       3
# 98299                                   2                       4
# 70039                                   3                       3
#
#         Gate Location  ...  Inflight Entertainment  On-Board Service  \
# id                     ...
# 114960              2  ...                       4                 4
# 43337               5  ...                       3                 1
# 74692               4  ...                       4                 3
# 98299               3  ...                       1                 2
# 70039               3  ...                       4                 1
#
#         Leg Room Service  Baggage Handling  Checkin Service  Inflight Service  \
# id
# 114960                 4                 4                4                 4
# 43337                  1                 1                2                 1
# 74692                  5                 5                3                 4
# 98299                  3                 3                2                 4
# 70039                  2                 1                4                 4
#
#         Cleanliness  Departure Delay In Minutes  Arrival Delay In Minutes  \
# id
# 114960            3                          24                      21.0
# 43337             3                           0                       1.0
# 74692             4                           3                       0.0
# 98299             1                           0                       0.0
# 70039             4                           0                       0.0
#
#         Satisfaction
# id
# 114960           Yes
# 43337             No
# 74692             No
# 98299             No
# 70039            Yes
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (120634, 23)

# %%
df.tail()
# Out:
#         Gender      Customer Type  Age   Type Of Travel     Class  \
# id
# 2944    Female     Loyal Customer   49  Business travel  Business
# 10732     Male     Loyal Customer   33  Business travel       Eco
# 22247     Male     Loyal Customer   63  Business travel  Business
# 102432  Female     Loyal Customer   28  Personal Travel       Eco
# 74494     Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight Wifi Service  \
# id
# 2944               1813                      2
# 10732               158                      2
# 22247               143                      1
# 102432              223                      4
# 74494              1205                      3
#
#         Departure/Arrival Time Convenient  Ease Of Online Booking  \
# id
# 2944                                    2                       2
# 10732                                   4                       4
# 22247                                   1                       1
# 102432                                  4                       4
# 74494                                   3                       3
#
#         Gate Location  ...  Inflight Entertainment  On-Board Service  \
# id                     ...
# 2944                2  ...                       5                 5
# 10732               4  ...                       2                 4
# 22247               1  ...                       5                 5
# 102432              4  ...                       4                 3
# 74494               4  ...                       2                 5
#
#         Leg Room Service  Baggage Handling  Checkin Service  Inflight Service  \
# id
# 2944                   5                 5                3                 5
# 10732                  3                 4                2                 4
# 22247                  5                 4                5                 5
# 102432                 4                 4                3                 4
# 74494                  4                 5                4                 4
#
#         Cleanliness  Departure Delay In Minutes  Arrival Delay In Minutes  \
# id
# 2944              5                           0                       0.0
# 10732             2                          92                      84.0
# 22247             3                           0                      27.0
# 102432            4                           0                       0.0
# 74494             2                           0                       0.0
#
#         Satisfaction
# id
# 2944             Yes
# 10732             No
# 22247            Yes
# 102432            No
# 74494             No
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120634 entries, 114960 to 74494
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             120634 non-null  object
#  1   Customer Type                      120634 non-null  object
#  2   Age                                120634 non-null  int64
#  3   Type Of Travel                     120634 non-null  object
#  4   Class                              120634 non-null  object
#  5   Flight Distance                    120634 non-null  int64
#  6   Inflight Wifi Service              120634 non-null  int64
#  7   Departure/Arrival Time Convenient  120634 non-null  int64
#  8   Ease Of Online Booking             120634 non-null  int64
#  9   Gate Location                      120634 non-null  int64
#  10  Food And Drink                     120634 non-null  int64
#  11  Online Boarding                    120634 non-null  int64
#  12  Seat Comfort                       120634 non-null  int64
#  13  Inflight Entertainment             120634 non-null  int64
#  14  On-Board Service                   120634 non-null  int64
#  15  Leg Room Service                   120634 non-null  int64
#  16  Baggage Handling                   120634 non-null  int64
#  17  Checkin Service                    120634 non-null  int64
#  18  Inflight Service                   120634 non-null  int64
#  19  Cleanliness                        120634 non-null  int64
#  20  Departure Delay In Minutes         120634 non-null  int64
#  21  Arrival Delay In Minutes           120634 non-null  float64
#  22  Satisfaction                       120634 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 22.1+ MB

# %%
df.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type Of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight Wifi Service                0
# Departure/Arrival Time Convenient    0
# Ease Of Online Booking               0
# Gate Location                        0
# Food And Drink                       0
# Online Boarding                      0
# Seat Comfort                         0
# Inflight Entertainment               0
# On-Board Service                     0
# Leg Room Service                     0
# Baggage Handling                     0
# Checkin Service                      0
# Inflight Service                     0
# Cleanliness                          0
# Departure Delay In Minutes           0
# Arrival Delay In Minutes             0
# Satisfaction                         0
# dtype: int64

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight Wifi Service  \
# count  120634.000000    120634.000000          120634.000000
# mean       39.405599      1179.093614               2.731610
# std        15.112555       995.690255               1.329955
# min         7.000000        31.000000               0.000000
# 25%        27.000000       409.000000               2.000000
# 50%        40.000000       837.000000               3.000000
# 75%        51.000000      1712.750000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival Time Convenient  Ease Of Online Booking  \
# count                      120634.000000           120634.000000
# mean                            3.060182                2.756172
# std                             1.526700                1.402755
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate Location  Food And Drink  Online Boarding   Seat Comfort  \
# count  120634.000000   120634.000000    120634.000000  120634.000000
# mean        2.977278        3.204892         3.247625       3.436801
# std         1.278528        1.330595         1.350784       1.319666
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight Entertainment  On-Board Service  Leg Room Service  \
# count           120634.000000     120634.000000     120634.000000
# mean                 3.358506          3.378724          3.347846
# std                  1.334342          1.288768          1.318111
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage Handling  Checkin Service  Inflight Service    Cleanliness  \
# count     120634.000000    120634.000000     120634.000000  120634.000000
# mean           3.625437         3.299609          3.637043       3.285757
# std            1.183041         1.269417          1.179239       1.315270
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         2.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay In Minutes  Arrival Delay In Minutes
# count               120634.000000             120634.000000
# mean                    15.050516                 15.434032
# std                     38.576343                 39.089339
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     13.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
# Univariate Analysis

# %%
df['Gender'].value_counts()
# Out:
# Female    61256
# Male      59378
# Name: Gender, dtype: int64

# %%
a2=df['Satisfaction'].value_counts()
a2=a2[::-1]

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=df['Satisfaction'])
plt.title('Satisfaction Count')
for i, v in enumerate(a2):
    plt.text(i, v, str(v), ha='center')
plt.show()

# %%
a1=df['Type Of Travel'].value_counts().rename_axis('Travel_Type').reset_index(name='count')
a1
# Out:
#        Travel_Type  count
# 0  Business travel  83380
# 1  Personal Travel  37254

# %%
your_explode=[0, 0]
plt.pie(a1['count'], labels=a1.Travel_Type, autopct='%1.5f%%', explode=(0,0.05), startangle=90)
plt.show()

# %%
a3=df['Customer Type'].value_counts()
a3
# Out:
# Loyal Customer       98571
# disloyal Customer    22063
# Name: Customer Type, dtype: int64

# %%
sns.countplot(df['Customer Type'])
for i, v in enumerate(a3):
    plt.text(i, v, str(v), ha='center')
plt.show()
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Inflight Wifi Service'].value_counts()
# Out:
# 2    29962
# 3    29871
# 4    23121
# 1    20659
# 5    13369
# 0     3652
# Name: Inflight Wifi Service, dtype: int64

# %%
df['Departure/Arrival Time Convenient'].value_counts()
# Out:
# 4    29593
# 5    26102
# 3    20764
# 2    19987
# 1    18014
# 0     6174
# Name: Departure/Arrival Time Convenient, dtype: int64

# %%
df['Ease Of Online Booking'].value_counts()
# Out:
# 3    28217
# 2    27904
# 4    22669
# 1    20318
# 5    16207
# 0     5319
# Name: Ease Of Online Booking, dtype: int64

# %%
df['Inflight Entertainment'].value_counts()
# Out:
# 4    34168
# 5    29328
# 3    22162
# 2    20392
# 1    14568
# 0       16
# Name: Inflight Entertainment, dtype: int64

# %%
a4=df['Class'].value_counts()
a4
# Out:
# Business    57159
# Eco         54596
# Eco Plus     8879
# Name: Class, dtype: int64

# %%
sns.countplot(x=df['Class'])
for i, v in enumerate(a4):
    plt.text(i, v, str(v), ha='center')
plt.show()

# %%
# Here we can see that most of the passenger travel through business and eco class

# %%
df['Cleanliness'].value_counts()
# Out:
# 4    31511
# 3    28346
# 5    26453
# 2    18717
# 1    15593
# 0       14
# Name: Cleanliness, dtype: int64

# %%
df['Seat Comfort'].value_counts()
# Out:
# 4    36794
# 5    30669
# 3    21827
# 2    17250
# 1    14093
# 0        1
# Name: Seat Comfort, dtype: int64

# %%
df['Inflight Service'].value_counts()
# Out:
# 4    43839
# 5    31529
# 3    23568
# 2    13351
# 1     8344
# 0        3
# Name: Inflight Service, dtype: int64

# %%
df['Food And Drink'].value_counts()
# Out:
# 4    28450
# 5    25968
# 3    25749
# 2    25389
# 1    14954
# 0      124
# Name: Food And Drink, dtype: int64

# %%
df['Checkin Service'].value_counts()
# Out:
# 4    33587
# 3    32780
# 5    23986
# 2    15147
# 1    15133
# 0        1
# Name: Checkin Service, dtype: int64

# %%
df['On-Board Service'].value_counts()
# Out:
# 4    35859
# 5    27315
# 3    26527
# 2    17067
# 1    13863
# 0        3
# Name: On-Board Service, dtype: int64

# %%
# Bivariate analysis

# %%
x=pd.crosstab(df['Gender'], df['Satisfaction'])
x
# Out:
# Satisfaction     No    Yes
# Gender
# Female        35008  26248
# Male          33300  26078

# %%
fig=plt.figure(figsize=(10,4))
a6=sns.countplot(x=df['Gender'],hue=df["Satisfaction"],palette='tab10')

for i in a6.containers:
    a6.bar_label(i)
plt.title("Gender Satisfaction Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Satisfaction Distribution')

# %%
fig=plt.figure(figsize=(10,4))
a7=sns.countplot( x=df["Class"], hue=df["Satisfaction"], palette='viridis')
for bars in a7.containers:
    a7.bar_label(bars)
plt.title("Class wise Satisfaction")
# Out:
# Text(0.5, 1.0, 'Class wise Satisfaction')

# %%
sns.countplot( x=df["Customer Type"], hue=df["Class"], palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %%
sns.displot(data=df, x="Flight Distance", hue="Satisfaction", kind="kde", multiple="stack")

# %%
sns.countplot( x=df["Customer Type"], hue=df["Satisfaction"], palette='rocket')
# Out:
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %%
sns.displot(data=df, x="Class", hue="Inflight Wifi Service", multiple="dodge", palette='flare')

# %%
sns.countplot(x=df['Customer Type'],hue=df["Cleanliness"])
# Out:
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %%
sns.displot(data=df,x='Customer Type',hue="Ease Of Online Booking", col="Gender", multiple="dodge")

# %%
sns.displot(data=df,x='Customer Type',hue="Cleanliness", col="Type Of Travel", multiple="dodge")

# %%
sns.barplot(data=df, x='Inflight Service', y='Flight Distance')
# Out:
# <AxesSubplot:xlabel='Inflight Service', ylabel='Flight Distance'>

# %%
sns.displot(data=df, x="Flight Distance", hue="Type Of Travel", kind="kde",col="Customer Type", multiple="stack")

# %%
avg_Age=df.groupby(['Class', 'Gender'], as_index=False)['Age'].mean().sort_values(by='Age', ascending = False)
sns.set(rc={'figure.figsize':(15,6)})
sns.barplot(data=avg_Age, x='Class', y='Age', hue='Gender', palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Age'>

# %% [markdown]
# # conclusion
#  We can see that most of the people who are travel through the business class they are satisfied.
#  But the people who are travel with Eco class are not satisfied.
#  Also We can see most of the passenger prefferd short distance flight.

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder(cols=['Gender','Customer Type','Type Of Travel','Satisfaction','Class'])

df1 = encoder.fit_transform(df)

# %%
df1.head()
# Out:
#         Gender  Customer Type  Age  Type Of Travel  Class  Flight Distance  \
# id
# 114960       1              1   55               1      1             2001
# 43337        2              1   36               1      2              387
# 74692        1              1   17               2      2             1235
# 98299        1              1   11               2      2             1072
# 70039        2              1   39               1      2              183
#
#         Inflight Wifi Service  Departure/Arrival Time Convenient  \
# id
# 114960                      2                                  2
# 43337                       3                                  5
# 74692                       3                                  4
# 98299                       3                                  2
# 70039                       4                                  3
#
#         Ease Of Online Booking  Gate Location  ...  Inflight Entertainment  \
# id                                             ...
# 114960                       2              2  ...                       4
# 43337                        2              5  ...                       3
# 74692                        3              4  ...                       4
# 98299                        4              3  ...                       1
# 70039                        3              3  ...                       4
#
#         On-Board Service  Leg Room Service  Baggage Handling  Checkin Service  \
# id
# 114960                 4                 4                 4                4
# 43337                  1                 1                 1                2
# 74692                  3                 5                 5                3
# 98299                  2                 3                 3                2
# 70039                  1                 2                 1                4
#
#         Inflight Service  Cleanliness  Departure Delay In Minutes  \
# id
# 114960                 4            3                          24
# 43337                  1            3                           0
# 74692                  4            4                           3
# 98299                  4            1                           0
# 70039                  4            4                           0
#
#         Arrival Delay In Minutes  Satisfaction
# id
# 114960                      21.0             1
# 43337                        1.0             2
# 74692                        0.0             2
# 98299                        0.0             2
# 70039                        0.0             1
#
# [5 rows x 23 columns]

# %%
df1.corr()
# Out:
#                                      Gender  Customer Type       Age  \
# Gender                             1.000000      -0.029671  0.008382
# Customer Type                     -0.029671       1.000000 -0.282222
# Age                                0.008382      -0.282222  1.000000
# Type Of Travel                     0.008541      -0.307651 -0.044152
# Class                             -0.011079       0.045349 -0.114396
# Flight Distance                    0.004189      -0.225182  0.097798
# Inflight Wifi Service              0.005554      -0.007892  0.016279
# Departure/Arrival Time Convenient  0.008032      -0.207409  0.035533
# Ease Of Online Booking             0.005934      -0.018840  0.021922
# Gate Location                     -0.000426       0.006714 -0.001530
# Food And Drink                     0.001843      -0.056430  0.021856
# Online Boarding                   -0.046480      -0.188265  0.204329
# Seat Comfort                      -0.030888      -0.154954  0.155509
# Inflight Entertainment             0.003400      -0.106092  0.072877
# On-Board Service                   0.005238      -0.058215  0.057177
# Leg Room Service                   0.029859      -0.048472  0.038175
# Baggage Handling                   0.034686       0.020300 -0.047092
# Checkin Service                    0.007326      -0.032894  0.031023
# Inflight Service                   0.037032       0.018219 -0.050481
# Cleanliness                        0.003131      -0.080207  0.050025
# Departure Delay In Minutes         0.003820       0.002996 -0.009209
# Arrival Delay In Minutes           0.002174       0.003542 -0.010936
# Satisfaction                      -0.010783       0.187741 -0.132602
#
#                                    Type Of Travel     Class  Flight Distance  \
# Gender                                   0.008541 -0.011079         0.004189
# Customer Type                           -0.307651  0.045349        -0.225182
# Age                                     -0.044152 -0.114396         0.097798
# Type Of Travel                           1.000000  0.480232        -0.268948
# Class                                    0.480232  1.000000        -0.431143
# Flight Distance                         -0.268948 -0.431143         1.000000
# Inflight Wifi Service                   -0.107192 -0.020462         0.004788
# Departure/Arrival Time Convenient        0.259272  0.086517        -0.019558
# Ease Of Online Booking                  -0.134285 -0.094460         0.065283
# Gate Location                           -0.031808 -0.006595         0.005444
# Food And Drink                          -0.067828 -0.077145         0.055643
# Online Boarding                         -0.219809 -0.291745         0.213399
# Seat Comfort                            -0.122306 -0.205723         0.154650
# Inflight Entertainment                  -0.152631 -0.180160         0.130116
# On-Board Service                        -0.053809 -0.207584         0.111812
# Leg Room Service                        -0.136826 -0.196494         0.133382
# Baggage Handling                        -0.026694 -0.162063         0.065000
# Checkin Service                          0.024684 -0.152075         0.071760
# Inflight Service                        -0.016925 -0.155364         0.059609
# Cleanliness                             -0.081695 -0.125016         0.093607
# Departure Delay In Minutes              -0.006009  0.008055         0.003414
# Arrival Delay In Minutes                -0.005856  0.012692        -0.001057
# Satisfaction                             0.449120  0.441865        -0.297801
#
#                                    Inflight Wifi Service  \
# Gender                                          0.005554
# Customer Type                                  -0.007892
# Age                                             0.016279
# Type Of Travel                                 -0.107192
# Class                                          -0.020462
# Flight Distance                                 0.004788
# Inflight Wifi Service                           1.000000
# Departure/Arrival Time Convenient               0.341516
# Ease Of Online Booking                          0.712044
# Gate Location                                   0.335079
# Food And Drink                                  0.134197
# Online Boarding                                 0.458041
# Seat Comfort                                    0.122709
# Inflight Entertainment                          0.210968
# On-Board Service                                0.118366
# Leg Room Service                                0.159563
# Baggage Handling                                0.117879
# Checkin Service                                 0.042823
# Inflight Service                                0.107813
# Cleanliness                                     0.133178
# Departure Delay In Minutes                     -0.016415
# Arrival Delay In Minutes                       -0.018046
# Satisfaction                                   -0.284812
#
#                                    Departure/Arrival Time Convenient  \
# Gender                                                      0.008032
# Customer Type                                              -0.207409
# Age                                                         0.035533
# Type Of Travel                                              0.259272
# Class                                                       0.086517
# Flight Distance                                            -0.019558
# Inflight Wifi Service                                       0.341516
# Departure/Arrival Time Convenient                           1.000000
# Ease Of Online Booking                                      0.437039
# Gate Location                                               0.446704
# Food And Drink                                              0.000512
# Online Boarding                                             0.073176
# Seat Comfort                                                0.010047
# Inflight Entertainment                                     -0.008821
# On-Board Service                                            0.068111
# Leg Room Service                                            0.011397
# Baggage Handling                                            0.072022
# Checkin Service                                             0.095299
# Inflight Service                                            0.073156
# Cleanliness                                                 0.010743
# Departure Delay In Minutes                                  0.000992
# Arrival Delay In Minutes                                   -0.000841
# Satisfaction                                                0.054978
#
#                                    Ease Of Online Booking  Gate Location  ...  \
# Gender                                           0.005934      -0.000426  ...
# Customer Type                                   -0.018840       0.006714  ...
# Age                                              0.021922      -0.001530  ...
# Type Of Travel                                  -0.134285      -0.031808  ...
# Class                                           -0.094460      -0.006595  ...
# Flight Distance                                  0.065283       0.005444  ...
# Inflight Wifi Service                            0.712044       0.335079  ...
# Departure/Arrival Time Convenient                0.437039       0.446704  ...
# Ease Of Online Booking                           1.000000       0.460478  ...
# Gate Location                                    0.460478       1.000000  ...
# Food And Drink                                   0.030377      -0.002141  ...
# Online Boarding                                  0.404478       0.002581  ...
# Seat Comfort                                     0.028297       0.003013  ...
# Inflight Entertainment                           0.046994       0.003249  ...
# On-Board Service                                 0.037760      -0.028741  ...
# Leg Room Service                                 0.109292      -0.005394  ...
# Baggage Handling                                 0.037112       0.000440  ...
# Checkin Service                                  0.007717      -0.038597  ...
# Inflight Service                                 0.033450       0.000309  ...
# Cleanliness                                      0.015560      -0.006274  ...
# Departure Delay In Minutes                      -0.005103       0.006466  ...
# Arrival Delay In Minutes                        -0.007016       0.006102  ...
# Satisfaction                                    -0.167707       0.002657  ...
#
#                                    Inflight Entertainment  On-Board Service  \
# Gender                                           0.003400          0.005238
# Customer Type                                   -0.106092         -0.058215
# Age                                              0.072877          0.057177
# Type Of Travel                                  -0.152631         -0.053809
# Class                                           -0.180160         -0.207584
# Flight Distance                                  0.130116          0.111812
# Inflight Wifi Service                            0.210968          0.118366
# Departure/Arrival Time Convenient               -0.008821          0.068111
# Ease Of Online Booking                           0.046994          0.037760
# Gate Location                                    0.003249         -0.028741
# Food And Drink                                   0.623978          0.055587
# Online Boarding                                  0.283092          0.149277
# Seat Comfort                                     0.610308          0.126210
# Inflight Entertainment                           1.000000          0.416351
# On-Board Service                                 0.416351          1.000000
# Leg Room Service                                 0.296768          0.355312
# Baggage Handling                                 0.375405          0.516790
# Checkin Service                                  0.117350          0.242077
# Inflight Service                                 0.403821          0.547850
# Cleanliness                                      0.691154          0.118624
# Departure Delay In Minutes                      -0.028012         -0.030727
# Arrival Delay In Minutes                        -0.030881         -0.034710
# Satisfaction                                    -0.400317         -0.319353
#
#                                    Leg Room Service  Baggage Handling  \
# Gender                                     0.029859          0.034686
# Customer Type                             -0.048472          0.020300
# Age                                        0.038175         -0.047092
# Type Of Travel                            -0.136826         -0.026694
# Class                                     -0.196494         -0.162063
# Flight Distance                            0.133382          0.065000
# Inflight Wifi Service                      0.159563          0.117879
# Departure/Arrival Time Convenient          0.011397          0.072022
# Ease Of Online Booking                     0.109292          0.037112
# Gate Location                             -0.005394          0.000440
# Food And Drink                             0.030128          0.032371
# Online Boarding                            0.118431          0.078703
# Seat Comfort                               0.098848          0.070921
# Inflight Entertainment                     0.296768          0.375405
# On-Board Service                           0.355312          0.516790
# Leg Room Service                           1.000000          0.368542
# Baggage Handling                           0.368542          1.000000
# Checkin Service                            0.149766          0.231884
# Inflight Service                           0.366616          0.625328
# Cleanliness                                0.092088          0.092543
# Departure Delay In Minutes                 0.014434         -0.003269
# Arrival Delay In Minutes                   0.011636         -0.006731
# Satisfaction                              -0.309881         -0.244476
#
#                                    Checkin Service  Inflight Service  \
# Gender                                    0.007326          0.037032
# Customer Type                            -0.032894          0.018219
# Age                                       0.031023         -0.050481
# Type Of Travel                            0.024684         -0.016925
# Class                                    -0.152075         -0.155364
# Flight Distance                           0.071760          0.059609
# Inflight Wifi Service                     0.042823          0.107813
# Departure/Arrival Time Convenient         0.095299          0.073156
# Ease Of Online Booking                    0.007717          0.033450
# Gate Location                            -0.038597          0.000309
# Food And Drink                            0.083189          0.033115
# Online Boarding                           0.199241          0.069575
# Seat Comfort                              0.185425          0.065767
# Inflight Entertainment                    0.117350          0.403821
# On-Board Service                          0.242077          0.547850
# Leg Room Service                          0.149766          0.366616
# Baggage Handling                          0.231884          0.625328
# Checkin Service                           1.000000          0.234766
# Inflight Service                          0.234766          1.000000
# Cleanliness                               0.173549          0.087293
# Departure Delay In Minutes               -0.016385         -0.053586
# Arrival Delay In Minutes                 -0.019435         -0.058981
# Satisfaction                             -0.230151         -0.240977
#
#                                    Cleanliness  Departure Delay In Minutes  \
# Gender                                0.003131                    0.003820
# Customer Type                        -0.080207                    0.002996
# Age                                   0.050025                   -0.009209
# Type Of Travel                       -0.081695                   -0.006009
# Class                                -0.125016                    0.008055
# Flight Distance                       0.093607                    0.003414
# Inflight Wifi Service                 0.133178                   -0.016415
# Departure/Arrival Time Convenient     0.010743                    0.000992
# Ease Of Online Booking                0.015560                   -0.005103
# Gate Location                        -0.006274                    0.006466
# Food And Drink                        0.658188                   -0.029370
# Online Boarding                       0.328239                   -0.017693
# Seat Comfort                          0.677559                   -0.026496
# Inflight Entertainment                0.691154                   -0.028012
# On-Board Service                      0.118624                   -0.030727
# Leg Room Service                      0.092088                    0.014434
# Baggage Handling                      0.092543                   -0.003269
# Checkin Service                       0.173549                   -0.016385
# Inflight Service                      0.087293                   -0.053586
# Cleanliness                           1.000000                   -0.013287
# Departure Delay In Minutes           -0.013287                    1.000000
# Arrival Delay In Minutes             -0.015262                    0.966324
# Satisfaction                         -0.305041                    0.051215
#
#                                    Arrival Delay In Minutes  Satisfaction
# Gender                                             0.002174     -0.010783
# Customer Type                                      0.003542      0.187741
# Age                                               -0.010936     -0.132602
# Type Of Travel                                    -0.005856      0.449120
# Class                                              0.012692      0.441865
# Flight Distance                                   -0.001057     -0.297801
# Inflight Wifi Service                             -0.018046     -0.284812
# Departure/Arrival Time Convenient                 -0.000841      0.054978
# Ease Of Online Booking                            -0.007016     -0.167707
# Gate Location                                      0.006102      0.002657
# Food And Drink                                    -0.031943     -0.210444
# Online Boarding                                   -0.020840     -0.496340
# Seat Comfort                                      -0.029191     -0.343894
# Inflight Entertainment                            -0.030881     -0.400317
# On-Board Service                                  -0.034710     -0.319353
# Leg Room Service                                   0.011636     -0.309881
# Baggage Handling                                  -0.006731     -0.244476
# Checkin Service                                   -0.019435     -0.230151
# Inflight Service                                  -0.058981     -0.240977
# Cleanliness                                       -0.015262     -0.305041
# Departure Delay In Minutes                         0.966324      0.051215
# Arrival Delay In Minutes                           1.000000      0.058002
# Satisfaction                                       0.058002      1.000000
#
# [23 rows x 23 columns]

# %%
df.info().describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120634 entries, 114960 to 74494
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             120634 non-null  object
#  1   Customer Type                      120634 non-null  object
#  2   Age                                120634 non-null  int64
#  3   Type Of Travel                     120634 non-null  object
#  4   Class                              120634 non-null  object
#  5   Flight Distance                    120634 non-null  int64
#  6   Inflight Wifi Service              120634 non-null  int64
#  7   Departure/Arrival Time Convenient  120634 non-null  int64
#  8   Ease Of Online Booking             120634 non-null  int64
#  9   Gate Location                      120634 non-null  int64
#  10  Food And Drink                     120634 non-null  int64
#  11  Online Boarding                    120634 non-null  int64
#  12  Seat Comfort                       120634 non-null  int64
#  13  Inflight Entertainment             120634 non-null  int64
#  14  On-Board Service                   120634 non-null  int64
#  15  Leg Room Service                   120634 non-null  int64
#  16  Baggage Handling                   120634 non-null  int64
#  17  Checkin Service                    120634 non-null  int64
#  18  Inflight Service                   120634 non-null  int64
#  19  Cleanliness                        120634 non-null  int64
#  20  Departure Delay In Minutes         120634 non-null  int64
#  21  Arrival Delay In Minutes           120634 non-null  float64
#  22  Satisfaction                       120634 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 26.1+ MB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 df.info().describe()
#
# AttributeError: 'NoneType' object has no attribute 'describe'
